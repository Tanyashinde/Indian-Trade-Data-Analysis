# %% [markdown]
# ## Indian Trade Data Analysis

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# Import libraries
import pandas as pd
import numpy as mp
# %matplotlib inline
import matplotlib.pyplot as plt

# %% [markdown]
# ### 1.Content
# ##### India is one of the fastest developing nations of the world and trade between nations is the major component
# ##### of any developing nation. This dataset includes the trade data for India for commodities in the HS2 basket.
# ##### The dataset consists of trade values for export and import of commodities in million US$.
#
# A few questions that can be answered using this dataset are:
#
# 1.What did India export the most in any given year?
# 2.Which commodity forms a major chunk of trade? Does it conform to theories of international trade?
# 3.How has the trade between India and any given country grown over time?

# %% [markdown]
# ##### 2. Reading the Dataset

# %%
df= pd.read_csv("2018-2010_export.csv",index_col=0)
df.head()
# Out:
#                                                 Commodity  value  \
# HSCode
# 2                             MEAT AND EDIBLE MEAT OFFAL.   0.18
# 3       FISH AND CRUSTACEANS, MOLLUSCS AND OTHER AQUAT...   0.00
# 4       DAIRY PRODUCE; BIRDS' EGGS; NATURAL HONEY; EDI...  12.48
# 6       LIVE TREES AND OTHER PLANTS; BULBS; ROOTS AND ...   0.00
# 7         EDIBLE VEGETABLES AND CERTAIN ROOTS AND TUBERS.   1.89
#
#                 country  year
# HSCode
# 2       AFGHANISTAN TIS  2018
# 3       AFGHANISTAN TIS  2018
# 4       AFGHANISTAN TIS  2018
# 6       AFGHANISTAN TIS  2018
# 7       AFGHANISTAN TIS  2018

# %%
df
# Out:
#                                                 Commodity  value  \
# HSCode
# 2                             MEAT AND EDIBLE MEAT OFFAL.   0.18
# 3       FISH AND CRUSTACEANS, MOLLUSCS AND OTHER AQUAT...   0.00
# 4       DAIRY PRODUCE; BIRDS' EGGS; NATURAL HONEY; EDI...  12.48
# 6       LIVE TREES AND OTHER PLANTS; BULBS; ROOTS AND ...   0.00
# 7         EDIBLE VEGETABLES AND CERTAIN ROOTS AND TUBERS.   1.89
# ...                                                   ...    ...
# 95      TOYS, GAMES AND SPORTS REQUISITES; PARTS AND A...   0.03
# 96                   MISCELLANEOUS MANUFACTURED ARTICLES.   0.45
# 97          WORKS OF ART COLLECTORS' PIECES AND ANTIQUES.   0.00
# 98                      PROJECT GOODS; SOME SPECIAL USES.   0.00
# 99                                   MISCELLANEOUS GOODS.   0.07
#
#                 country  year
# HSCode
# 2       AFGHANISTAN TIS  2018
# 3       AFGHANISTAN TIS  2018
# 4       AFGHANISTAN TIS  2018
# 6       AFGHANISTAN TIS  2018
# ...

# %%
#Number of rows and columns imformation about dataset
df.shape
# Out:
# (137023, 4)

# %%
#Data types of each column
df.dtypes
# Out:
# Commodity     object
# value        float64
# country       object
# year           int64
# dtype: object

# %% [markdown]
# ## 3. Getting our Data Ready
# #### Filling or disregarding missing values

# %%
df.isnull().sum()
# Out:
# Commodity        0
# value        14038
# country          0
# year             0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# Commodity    0
# value        0
# country      0
# year         0
# dtype: int64

# %%
# After removing null values from dataset
df.shape
# Out:
# (122985, 4)

# %%
df
# Out:
#                                                 Commodity  value  \
# HSCode
# 2                             MEAT AND EDIBLE MEAT OFFAL.   0.18
# 3       FISH AND CRUSTACEANS, MOLLUSCS AND OTHER AQUAT...   0.00
# 4       DAIRY PRODUCE; BIRDS' EGGS; NATURAL HONEY; EDI...  12.48
# 6       LIVE TREES AND OTHER PLANTS; BULBS; ROOTS AND ...   0.00
# 7         EDIBLE VEGETABLES AND CERTAIN ROOTS AND TUBERS.   1.89
# ...                                                   ...    ...
# 95      TOYS, GAMES AND SPORTS REQUISITES; PARTS AND A...   0.03
# 96                   MISCELLANEOUS MANUFACTURED ARTICLES.   0.45
# 97          WORKS OF ART COLLECTORS' PIECES AND ANTIQUES.   0.00
# 98                      PROJECT GOODS; SOME SPECIAL USES.   0.00
# 99                                   MISCELLANEOUS GOODS.   0.07
#
#                 country  year
# HSCode
# 2       AFGHANISTAN TIS  2018
# 3       AFGHANISTAN TIS  2018
# 4       AFGHANISTAN TIS  2018
# 6       AFGHANISTAN TIS  2018
# ...

# %% [markdown]
# ## Now lets try to solve our first Question :
# ## 1.What did India export the most in any given year?

# %%
df_18= df[df["year"]==2018]
df_18
# Out:
#                                                 Commodity  value  \
# HSCode
# 2                             MEAT AND EDIBLE MEAT OFFAL.   0.18
# 3       FISH AND CRUSTACEANS, MOLLUSCS AND OTHER AQUAT...   0.00
# 4       DAIRY PRODUCE; BIRDS' EGGS; NATURAL HONEY; EDI...  12.48
# 6       LIVE TREES AND OTHER PLANTS; BULBS; ROOTS AND ...   0.00
# 7         EDIBLE VEGETABLES AND CERTAIN ROOTS AND TUBERS.   1.89
# ...                                                   ...    ...
# 94      FURNITURE; BEDDING, MATTRESSES, MATTRESS SUPPO...   0.22
# 95      TOYS, GAMES AND SPORTS REQUISITES; PARTS AND A...   0.01
# 96                   MISCELLANEOUS MANUFACTURED ARTICLES.   0.28
# 98                      PROJECT GOODS; SOME SPECIAL USES.   0.00
# 99                                   MISCELLANEOUS GOODS.   0.00
#
#                 country  year
# HSCode
# 2       AFGHANISTAN TIS  2018
# 3       AFGHANISTAN TIS  2018
# 4       AFGHANISTAN TIS  2018
# 6       AFGHANISTAN TIS  2018
# ...

# %%
df_18[df_18["Commodity"]=="MEAT AND EDIBLE MEAT OFFAL."]
# Out:
#                           Commodity    value          country  year
# HSCode
# 2       MEAT AND EDIBLE MEAT OFFAL.     0.18  AFGHANISTAN TIS  2018
# 2       MEAT AND EDIBLE MEAT OFFAL.    50.75          ALGERIA  2018
# 2       MEAT AND EDIBLE MEAT OFFAL.    27.31           ANGOLA  2018
# 2       MEAT AND EDIBLE MEAT OFFAL.     2.28          ARMENIA  2018
# 2       MEAT AND EDIBLE MEAT OFFAL.     0.51       AZERBAIJAN  2018
# ...                             ...      ...              ...   ...
# 2       MEAT AND EDIBLE MEAT OFFAL.     0.00          UKRAINE  2018
# 2       MEAT AND EDIBLE MEAT OFFAL.     0.15       UZBEKISTAN  2018
# 2       MEAT AND EDIBLE MEAT OFFAL.  1710.22  VIETNAM SOC REP  2018
# 2       MEAT AND EDIBLE MEAT OFFAL.     0.13    YEMEN REPUBLC  2018
# 2       MEAT AND EDIBLE MEAT OFFAL.     0.08           ZAMBIA  2018
#
# [76 rows x 4 columns]

# %%
df_18.sort_values('value',inplace=True,ascending=False)
df_18
# Out:
#                                                 Commodity     value  \
# HSCode
# 71      NATURAL OR CULTURED PEARLS,PRECIOUS OR SEMIPRE...  11140.21
# 71      NATURAL OR CULTURED PEARLS,PRECIOUS OR SEMIPRE...  10442.27
# 71      NATURAL OR CULTURED PEARLS,PRECIOUS OR SEMIPRE...  10418.15
# 27      MINERAL FUELS, MINERAL OILS AND PRODUCTS OF TH...   6367.54
# 27      MINERAL FUELS, MINERAL OILS AND PRODUCTS OF TH...   5877.28
# ...                                                   ...       ...
# 26                                    ORES, SLAG AND ASH.      0.00
# 22                        BEVERAGES, SPIRITS AND VINEGAR.      0.00
# 55                                MAN-MADE STAPLE FIBRES.      0.00
# 57             CARPETS AND OTHER TEXTILE FLOOR COVERINGS.      0.00
# 99                                   MISCELLANEOUS GOODS.      0.00
#
#              country  year
# HSCode
# 71         HONG KONG  2018
# 71             U S A  2018
# 71       U ARAB EMTS  2018
# ...

# %%
Top_10_trade= df_18[:10]
Top_10_trade
# Out:
#                                                 Commodity     value  \
# HSCode
# 71      NATURAL OR CULTURED PEARLS,PRECIOUS OR SEMIPRE...  11140.21
# 71      NATURAL OR CULTURED PEARLS,PRECIOUS OR SEMIPRE...  10442.27
# 71      NATURAL OR CULTURED PEARLS,PRECIOUS OR SEMIPRE...  10418.15
# 27      MINERAL FUELS, MINERAL OILS AND PRODUCTS OF TH...   6367.54
# 27      MINERAL FUELS, MINERAL OILS AND PRODUCTS OF TH...   5877.28
# 30                                PHARMACEUTICAL PRODUCTS   5389.73
# 27      MINERAL FUELS, MINERAL OILS AND PRODUCTS OF TH...   4364.22
# 84      NUCLEAR REACTORS, BOILERS, MACHINERY AND MECHA...   4026.34
# 29                                      ORGANIC CHEMICALS   3249.21
# 27      MINERAL FUELS, MINERAL OILS AND PRODUCTS OF TH...   2855.69
#
#             country  year
# HSCode
# 71        HONG KONG  2018
# 71            U S A  2018
# 71      U ARAB EMTS  2018
# 27      U ARAB EMTS  2018
# 27        SINGAPORE  2018
# 30            U S A  2018
# ...

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
plt.title('Top 10 Indian Trades from the year 2018')

values= Top_10_trade["value"]
countries= Top_10_trade["country"]
ax.pie(values,labels=countries,autopct='%1.2f%%')
plt.show()

# %% [markdown]
# # The most exported Commodity from the year 2018

# %%
Top_10_trade.head(1)
# Out:
#                                                 Commodity     value  \
# HSCode
# 71      NATURAL OR CULTURED PEARLS,PRECIOUS OR SEMIPRE...  11140.21
#
#           country  year
# HSCode
# 71      HONG KONG  2018

# %% [markdown]
# # 2. Which year had the most Exports?

# %%
df.head(20)
# Out:
#                                                 Commodity  value  \
# HSCode
# 2                             MEAT AND EDIBLE MEAT OFFAL.   0.18
# 3       FISH AND CRUSTACEANS, MOLLUSCS AND OTHER AQUAT...   0.00
# 4       DAIRY PRODUCE; BIRDS' EGGS; NATURAL HONEY; EDI...  12.48
# 6       LIVE TREES AND OTHER PLANTS; BULBS; ROOTS AND ...   0.00
# 7         EDIBLE VEGETABLES AND CERTAIN ROOTS AND TUBERS.   1.89
# 8       EDIBLE FRUIT AND NUTS; PEEL OR CITRUS FRUIT OR...  25.01
# 9                           COFFEE, TEA, MATE AND SPICES.  13.75
# 10                                               CEREALS.   0.75
# 11      PRODUCTS OF THE MILLING INDUSTRY; MALT; STARCH...   0.01
# 12      OIL SEEDS AND OLEA. FRUITS; MISC. GRAINS, SEED...  10.02
# 13      LAC; GUMS, RESINS AND OTHER VEGETABLE SAPS AND...   0.04
# 15      ANIMAL OR VEGETABLE FATS AND OILS AND THEIR CL...   0.37
# 17                        SUGARS AND SUGAR CONFECTIONERY.  15.92
# ...

# %%
most_trade= df.groupby("year").sum()
most_trade
# Out:
#           value
# year
# 2010  249801.18
# 2011  305948.28
# 2012  300384.32
# 2013  314388.61
# 2014  310321.02
# 2015  262274.30
# 2016  275835.27
# 2017  303507.85
# 2018  330058.64

# %%
most_trade.sort_values('value',inplace=True,ascending=False)
most_trade
# Out:
#           value
# year
# 2018  330058.64
# 2013  314388.61
# 2014  310321.02
# 2011  305948.28
# 2017  303507.85
# 2012  300384.32
# 2016  275835.27
# 2015  262274.30
# 2010  249801.18

# %%
# most_trade["value"].plot.hist();

most_trade["value"].plot();
plt.title('Treade values of each year from 2010-2018')
plt.xlabel('Year')
plt.ylabel('Trade Values')
plt.show()

# %% [markdown]
# # 3.Which commodity forms a major chunk of trade?

# %%
df.head(20)
# Out:
#                                                 Commodity  value  \
# HSCode
# 2                             MEAT AND EDIBLE MEAT OFFAL.   0.18
# 3       FISH AND CRUSTACEANS, MOLLUSCS AND OTHER AQUAT...   0.00
# 4       DAIRY PRODUCE; BIRDS' EGGS; NATURAL HONEY; EDI...  12.48
# 6       LIVE TREES AND OTHER PLANTS; BULBS; ROOTS AND ...   0.00
# 7         EDIBLE VEGETABLES AND CERTAIN ROOTS AND TUBERS.   1.89
# 8       EDIBLE FRUIT AND NUTS; PEEL OR CITRUS FRUIT OR...  25.01
# 9                           COFFEE, TEA, MATE AND SPICES.  13.75
# 10                                               CEREALS.   0.75
# 11      PRODUCTS OF THE MILLING INDUSTRY; MALT; STARCH...   0.01
# 12      OIL SEEDS AND OLEA. FRUITS; MISC. GRAINS, SEED...  10.02
# 13      LAC; GUMS, RESINS AND OTHER VEGETABLE SAPS AND...   0.04
# 15      ANIMAL OR VEGETABLE FATS AND OILS AND THEIR CL...   0.37
# 17                        SUGARS AND SUGAR CONFECTIONERY.  15.92
# ...

# %%
com_trade= df.groupby(['Commodity'])['value'].sum().reset_index()

# %%
com_trade
# Out:
#                                             Commodity     value
# 0            AIRCRAFT, SPACECRAFT, AND PARTS THEREOF.  28219.85
# 1   ALBUMINOIDAL SUBSTANCES; MODIFIED STARCHES; GL...   2384.15
# 2                     ALUMINIUM AND ARTICLES THEREOF.  25407.12
# 3   ANIMAL OR VEGETABLE FATS AND OILS AND THEIR CL...   8774.07
# 4   ARMS AND AMMUNITION; PARTS AND ACCESSORIES THE...    656.08
# ..                                                ...       ...
# 93  WADDING, FELT AND NONWOVENS; SPACIAL YARNS; TW...   3208.55
# 94          WOOD AND ARTICLES OF WOOD; WOOD CHARCOAL.   3097.45
# 95  WOOL, FINE OR COARSE ANIMAL HAIR, HORSEHAIR YA...   1588.69
# 96      WORKS OF ART COLLECTORS' PIECES AND ANTIQUES.   1929.17
# 97                         ZINC AND ARTICLES THEREOF.   5662.82
#
# [98 rows x 2 columns]

# %%
com_trade.sort_values('value',inplace=True,ascending=False)

# %%
# fig,ax= plt.subplots()
# ax.barh(com_trade['Commodity'],com_trade['value'])

plt.figure(figsize=(100,100))
plt.title('Commodity trade values exported from 2010-1018')
plt.barh(com_trade['Commodity'],com_trade['value'], align='center')
plt.xlabel('Value in (million $)')
plt.ylabel('commodities')
plt.show()

# %%
top_10_trades= com_trade[:10]
top_10_trades
# Out:
#                                             Commodity      value
# 45  MINERAL FUELS, MINERAL OILS AND PRODUCTS OF TH...  434594.81
# 52  NATURAL OR CULTURED PEARLS,PRECIOUS OR SEMIPRE...  383341.86
# 92  VEHICLES OTHER THAN RAILWAY OR TRAMWAY ROLLING...  124502.75
# 54  NUCLEAR REACTORS, BOILERS, MACHINERY AND MECHA...  123810.69
# 58                                  ORGANIC CHEMICALS  113008.98
# 63                            PHARMACEUTICAL PRODUCTS  101792.69
# 23  ELECTRICAL MACHINERY AND EQUIPMENT AND PARTS T...   89819.84
# 35                                     IRON AND STEEL   76597.96
# 6   ARTICLES OF APPAREL AND CLOTHING ACCESSORIES, ...   75122.06
# 19                                            COTTON.   71284.27

# %%
plt.figure(figsize=(20,20))
plt.title('Top 10 commodity trade values from 2010-2018')
plt.barh(top_10_trades['Commodity'],top_10_trades['value'], align='center')
plt.xlabel('Value in (million $)')
plt.ylabel('commodities')
plt.show()

# %% [markdown]
# # 4.How has the trade between India and any given country grown over time?

# %%
country_trade= df[df['country']=="RUSSIA"]
country_trade
# Out:
#                                                 Commodity  value country  year
# HSCode
# 2                             MEAT AND EDIBLE MEAT OFFAL.  47.45  RUSSIA  2018
# 3       FISH AND CRUSTACEANS, MOLLUSCS AND OTHER AQUAT...  76.07  RUSSIA  2018
# 4       DAIRY PRODUCE; BIRDS' EGGS; NATURAL HONEY; EDI...   3.54  RUSSIA  2018
# 5       PRODUCTS OF ANIMAL ORIGIN, NOT ELSEWHERE SPECI...   0.02  RUSSIA  2018
# 6       LIVE TREES AND OTHER PLANTS; BULBS; ROOTS AND ...   0.10  RUSSIA  2018
# ...                                                   ...    ...     ...   ...
# 95      TOYS, GAMES AND SPORTS REQUISITES; PARTS AND A...   0.23  RUSSIA  2010
# 96                   MISCELLANEOUS MANUFACTURED ARTICLES.   3.69  RUSSIA  2010
# 97          WORKS OF ART COLLECTORS' PIECES AND ANTIQUES.   0.51  RUSSIA  2010
# 98                      PROJECT GOODS; SOME SPECIAL USES.   5.87  RUSSIA  2010
# 99                                   MISCELLANEOUS GOODS.  34.64  RUSSIA  2010
#
# ...

# %%
trade_over_time=country_trade.groupby(['year'])['value'].sum().reset_index()
trade_over_time
# Out:
#    year    value
# 0  2010  1689.32
# 1  2011  1778.18
# 2  2012  2295.60
# 3  2013  2121.14
# 4  2014  2096.90
# 5  2015  1587.71
# 6  2016  1936.92
# 7  2017  2113.25
# 8  2018  2389.29

# %%
trade_over_time.sort_values('value',inplace=True,ascending=True)

# %%
trade_over_time
# Out:
#    year    value
# 5  2015  1587.71
# 0  2010  1689.32
# 1  2011  1778.18
# 6  2016  1936.92
# 4  2014  2096.90
# 7  2017  2113.25
# 3  2013  2121.14
# 2  2012  2295.60
# 8  2018  2389.29

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
plt.title('trade values of each year from 2010-2018 between India and Russia')
ax.pie(trade_over_time['value'],labels=trade_over_time['year'],autopct='%1.2f%%')
plt.show()

# %%
trade_over_time.plot(x="year",y="value",kind="bar");
